# %%
#드라이브 마운트
#디렉토리 변경

# %%
#1.CSV데이터 읽어오기("wine.csv")

# %%
#2.특성데이터와 정답데이터 구분

# %%
#3.훈련/데스트 데이터 분리(test_size=0.2)

# %%
#훈련/테스트 데이터 표준화

# %%
#4.모델 훈련 및 정확도(LogisticRegression())

# %%
#모델의 기울기 및 절편

# %%
#4.모델 훈련 및 정확도(DecisionTreeClassifier(random_state=42))

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(10,7))
plot_tree(dt)
plt.show()

# %%
plt.figure(figsize=(10,7))
plot_tree(dt, max_depth=1, filled=True, feature_names=["alcohol","sugar","pH"])
plt.show()

# %% [markdown]
# ###지니불순도
# ![지니불순도](https://lucy-the-marketer.kr/wp-content/uploads/2020/12/gini-index-example-1.png)

# %%
#가지치기(DecisionTreeClassifier(max_depth=3, random_state=42))

# %%
plt.figure(figsize=(20,15))
plot_tree(dt2, filled=True, feature_names=["alcohol","sugar","pH"])
plt.show()

# %%
print(dt2.feature_importances_)
