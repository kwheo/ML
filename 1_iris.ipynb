# %%
# !pwd

# %%
import os
os.chdir('/content/drive/MyDrive/ML/Data')

# %%
# !pwd

# %% [markdown]
# ![iris](https://blog.kakaocdn.net/dn/t98JC/btsa6CuL7nS/O7D3FF4VGXRKLl7VjNhRMK/img.png)

# %%
#1. CSV 데이터 읽어오기

# %%
#head():1행~5행까지의 데이터를 보여줌

# %%
#info():결측치 여부를 표시

# %%
#describe():기술통계 값을 표시

# %%
#2. 특성데이터와 정답데이터 구분

# %%
#3. 모델 훈련

# %%
#4. 결과 예측
